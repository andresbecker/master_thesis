# %% [markdown]
# # Data Preprocessing
# ## Clipping + Linear Scaling + Mean subtraction
# <br>
# Rerf:<br>
# https://developers.google.com/machine-learning/data-prep/transform/normalization<br>
# https://machinelearningmastery.com/best-practices-for-preparing-and-augmenting-image-data-for-convolutional-neural-networks/<br>
# https://machinelearningmastery.com/how-to-improve-neural-network-stability-and-modeling-performance-with-data-scaling/<br>
# https://ieeexplore.ieee.org/abstract/document/7808140?casa_token=Iv-UkznWzlIAAAAA:HRAjUWBWSjres5Yosa4ka7dQEg35bvvUiuUa5HupQiA6WCIJV5yGiYiU-hKZuTKN21v_CeF6w-gE<br>

# %% [markdown]
# <img src="./Cheby_Theo.jpg" width=600/>

# %%
# For Development and debugging:
# Reload modul without restarting the kernel
#%load_ext autoreload
#%autoreload 2

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import copy
import multiprocessing
from multiprocessing import Pool
import socket
import sys
import time
import math

# %%
# Load external libraries
key = 'external_libs_path'
if socket.gethostname() == 'hughes-machine':
    external_libs_path = '/home/hhughes/Documents/Master_Thesis/Project/workspace/libs'
else:
    external_libs_path= '/storage/groups/ml01/code/andres.becker/master_thesis/workspace/libs'
print('External libs path: \n'+external_libs_path)

if not os.path.exists(external_libs_path):
    msg = 'External library path {} does not exist!'.format(external_libs_path)
    raise Exception(msg)

# Add EXTERNAL_LIBS_PATH to sys paths (for loading libraries)
sys.path.insert(1, external_libs_path)

#from test import plot_channel as plt_channel
# Out:
# External libs path:
# /home/hhughes/Documents/Master_Thesis/Project/workspace/libs

# %%
def load_channels(dataset_dir):
    temp_path = os.path.join(dataset_dir, 'channels.csv')
    channels_df = pd.read_csv(temp_path)
    input_channels = [
            "00_DAPI",
            "07_H2B",
            "01_CDK9_pT186",
            "03_CDK9",
            "05_GTF2B",
            "07_SETD1A",
            "08_H3K4me3",
            "09_SRRM2",
            "10_H3K27ac",
            "11_KPNA2_MAX",
            "12_RB1_pS807_S811",
            "13_PABPN1",
            "14_PCNA",
            "15_SON",
            "16_H3",
            "17_HDAC3",
            "19_KPNA1_MAX",
            "20_SP100",
            "21_NCL",
            "01_PABPC1",
            "02_CDK7",
            "03_RPS6",
            "05_Sm",
            "07_POLR2A",
            "09_CCNT1",
            "10_POL2RA_pS2",
            "11_PML",
            "12_YAP1",
            "13_POL2RA_pS5",
            "15_U2SNRNPB",
            "18_NONO",
            "20_ALYREF",
            "21_COIL"
        ]

    input_ids = channels_df.set_index('name').loc[input_channels].channel_id.sort_values().values
    
    return channels_df, input_ids

# %%
def get_train_ids(dataset_dir):
    # Load metadata file to get dataset splits
    temp_path = os.path.join(dataset_dir, 'filtered_metadata.csv')
    metadata_df = pd.read_csv(temp_path)
    train_mask = metadata_df.set == 'train'
    # load the ids corresponding to normal or DMSO and in the rain set
    #train_ids = set(metadata_df[train_mask].mapobject_id_cell.values.astype(str))
    train_ids = metadata_df[train_mask].mapobject_id_cell.values.astype(str)#[0:10]


    # Now list files available in the file system
    data_dir = os.path.join(dataset_dir, 'data')
    file_ids = set([id.split(".")[0] for id in os.listdir(data_dir)])

    # check if all ids in the metadata file are available in the file system
    print('Are all train cell ids in the file system? ', set(train_ids).issubset(file_ids))
    
    return train_ids

# %%
def load_imgs_pixels(dataset_dir, input_ids):

    # get total number of pixels to allocate np array
    n_pixels_per_channel = 0
    for cell_id in train_ids:
        temp_path = os.path.join(dataset_dir, 'data', cell_id+'.npz')
        temp_cell = np.load(temp_path)
        n_pixels_per_channel += temp_cell['mask'].sum()

    # load pixel values
    imgs_pixels = np.zeros((n_pixels_per_channel, len(input_ids))).astype(np.uint16)
    low_idx = 0
    up_idx = 0
    for i, cell_id in enumerate(train_ids):

        if (i % 100) == 0:
            print('Loading cell {}/{}'.format(i+1, len(train_ids)))

        temp_path = os.path.join(dataset_dir, 'data', cell_id+'.npz')
        temp_cell = np.load(temp_path)
        temp_img = temp_cell['img'][:,:,input_ids].astype(np.uint16)
        temp_mask = temp_cell['mask']

        low_idx = up_idx
        up_idx += temp_mask.sum()
        imgs_pixels[low_idx:up_idx, :] = temp_img[temp_mask]
    
    return imgs_pixels

# %%
def plot_kde(data, label, ax):
    sns.kdeplot(data,
                shade=True,
                bw_method=0.2,
                label=label,
                ax=ax)
    
def plot_clipping_apporach(channel_pixels, threshold, app_name, axs):
    
    # Copy to avoid rewritting original values
    temp_slide = copy.deepcopy(channel_pixels)
    
    # Apply clipping
    temp_slide[temp_slide > threshold] = threshold
    # Plot clipping
    label='{}={}'.format(app_name, str(round(threshold)))
    plot_kde(temp_slide, label, axs[1])
    
    # Apply lin scaling
    temp_slide /= threshold
    # Plot clipping + linear scaling (transformation)
    label='LT with {}={}'.format(app_name, str(round(threshold)))
    plot_kde(temp_slide, label, axs[2])
    
    # Apply mean subtraction
    mean = temp_slide.mean()
    temp_slide -= mean
    # Plot Clipping + Linear scaling + z-score
    label='{}, mu={}'.format(app_name, str(round(mean,2)))
    plot_kde(temp_slide, label, axs[3])
    
    
def plot_orginial_channel_dist_vs_transform(channel_pixels, channel_name):
    n_columns = 4
    
    channel_pixels = channel_pixels.astype(np.float32)

    figsize = (n_columns * 7,7)
    fig, axs = plt.subplots(1,n_columns, figsize=figsize)

    # Set plots title
    axs[0].title.set_text('Original '+channel_name+' masked pixel dist')
    axs[1].title.set_text('Clipped data dist')
    axs[2].title.set_text('Clipped and transformed data dist')
    axs[3].title.set_text('Clipping + LT + Mean subtraction')
    
    # plot original distribution
    plot_kde(channel_pixels, 'Unchanged dist', axs[0])

    # P_98 clipping----------------------------------------------------------
    p_98 = np.percentile(channel_pixels, 98, axis=0)
    app_name = 'P_98'
    plot_clipping_apporach(channel_pixels, p_98, app_name, axs)
    
    # P_99 clipping----------------------------------------------------------
    p_99 = np.percentile(channel_pixels, 99, axis=0)
    app_name = 'P_99'
    plot_clipping_apporach(channel_pixels, p_99, app_name, axs)
    
    # mean + 3*stddev clipping---------------------------------------------- 
    mean = channel_pixels.mean()
    stddev = channel_pixels.std()
    threshold = (mean + 3*stddev)
    app_name = 'mu+3sig'
    plot_clipping_apporach(channel_pixels, threshold, app_name, axs)

    # print axis legends
    for ax in axs:
        ax.legend()
    
    return fig

# %%
# timer to avoid job overlapping
# sleep for 3 hours
# !sleep 10800

# %%
# load data and create jobs queue

dataset_dir = '/data/Master_Thesis_data/datasets/184A1_hannah_imgs_no_split'
    
channels_df, input_ids = load_channels(dataset_dir)
    
train_ids = get_train_ids(dataset_dir)
    
train_pixels = load_imgs_pixels(dataset_dir, input_ids)
    
n_workers = multiprocessing.cpu_count()
n_channels = len(input_ids)

# get channel names for plots
channel_names = [channels_df.set_index('channel_id').loc[c].values[0] for c in range(n_channels)]
channel_names = [channel_name.split("_")[1:] for channel_name in channel_names]
channel_names = ["_".join(channel_name) for channel_name in channel_names]
# Out:
# Are all train cell ids in the file system?  True
# Loading cell 1/2962
# Loading cell 101/2962
# Loading cell 201/2962
# Loading cell 301/2962
# Loading cell 401/2962
# Loading cell 501/2962
# Loading cell 601/2962
# Loading cell 701/2962
# Loading cell 801/2962
# Loading cell 901/2962
# Loading cell 1001/2962
# Loading cell 1101/2962
# Loading cell 1201/2962
# Loading cell 1301/2962
# Loading cell 1401/2962
# Loading cell 1501/2962
# Loading cell 1601/2962
# Loading cell 1701/2962
# Loading cell 1801/2962
# Loading cell 1901/2962
# Loading cell 2001/2962
# Loading cell 2101/2962
# Loading cell 2201/2962
# Loading cell 2301/2962
# Loading cell 2401/2962
# Loading cell 2501/2962
# Loading cell 2601/2962
# Loading cell 2701/2962
# Loading cell 2801/2962
# Loading cell 2901/2962

# %%
# Devide data into jobs
jobs_per_exe = 4
n_jobs = math.ceil(n_channels / jobs_per_exe)
jobs = {}
low_idx = 0
up_idx = 0
for i in range(n_jobs):
    low_idx = up_idx
    up_idx += jobs_per_exe
    if up_idx > n_channels: up_idx = n_channels
    temp_range = range(low_idx, up_idx)
    
    jobs[i] = [(train_pixels[:,c], channel_names[c]) for c in temp_range]
del(train_pixels)
jobs
# Out:
# {0: [(array([14, 15,  7, ..., 23, 49, 44], dtype=uint16), 'DAPI'),
#   (array([ 67,  54,  51, ..., 148, 169, 168], dtype=uint16), 'H2B'),
#   (array([6, 2, 0, ..., 0, 0, 0], dtype=uint16), 'CDK9_pT186'),
#   (array([1, 8, 1, ..., 6, 0, 1], dtype=uint16), 'CDK9')],
#  1: [(array([ 18,  19,  18, ..., 212,  18,   6], dtype=uint16), 'GTF2B'),
#   (array([ 5, 10, 29, ...,  0,  0,  8], dtype=uint16), 'SETD1A'),
#   (array([1, 0, 6, ..., 0, 6, 4], dtype=uint16), 'H3K4me3'),
#   (array([ 4,  0,  4, ...,  0,  0, 10], dtype=uint16), 'SRRM2')],
#  2: [(array([ 5,  2,  5, ...,  0,  1, 13], dtype=uint16), 'H3K27ac'),
#   (array([88, 60, 65, ..., 80, 59, 56], dtype=uint16), 'KPNA2_MAX'),
#   (array([13, 14, 35, ...,  3,  0, 17], dtype=uint16), 'RB1_pS807_S811'),
#   (array([19,  6, 17, ..., 19, 13, 15], dtype=uint16), 'PABPN1')],
#  3: [(array([ 9,  0,  4, ...,  0, 13, 16], dtype=uint16), 'PCNA'),
#   (array([2, 2, 4, ..., 2, 0, 1], dtype=uint16), 'SON'),
#   (array([101,  54,  83, ..., 223, 137,  86], dtype=uint16), 'H3'),
#   (array([126, 103, 107, ..., 108, 393, 414], dtype=uint16), 'HDAC3')],
#  4: [(array([130, 127, 139, ..., 133, 157,  96], dtype=uint16), 'KPNA1_MAX'),
#   (array([0, 5, 5, ..., 2, 4, 0], dtype=uint16), 'SP100'),
#   (array([12,  0, 10, ...,  9,  1,  0], dtype=uint16), 'NCL'),
#   (array([31, 22, 14, ..., 38, 17, 28], dtype=uint16), 'PABPC1')],
#  5: [(array([18, 11, 15, ..., 16, 38, 13], dtype=uint16), 'CDK7'),
#   (array([29, 66, 37, ..., 43, 19, 27], dtype=uint16), 'RPS6'),
#   (array([34, 23, 16, ..., 19, 31, 31], dtype=uint16), 'Sm'),
#   (array([12,  5, 14, ..., 30, 14, 13], dtype=uint16), 'POLR2A')],
#  6: [(array([14, 11, 27, ..., 46,  9, 15], dtype=uint16), 'CCNT1'),
#   (array([27, 11, 15, ..., 37, 33, 46], dtype=uint16), 'POL2RA_pS2'),
#   (array([ 6, 10,  9, ...,  8,  5,  5], dtype=uint16), 'PML'),
#   (array([34, 46, 37, ..., 40, 78, 58], dtype=uint16), 'YAP1')],
#  7: [(array([ 43,  34,  38, ..., 160,  73,  82], dtype=uint16), 'POL2RA_pS5'),
#   (array([28, 36, 29, ..., 16, 39, 10], dtype=uint16), 'U2SNRNPB'),
#   (array([ 35,  22,  27, ..., 108,  73,  77], dtype=uint16), 'NONO'),
#   (array([ 34,  34,  55, ..., 127, 101, 104], dtype=uint16), 'ALYREF')],
#  8: [(array([3, 0, 4, ..., 2, 9, 3], dtype=uint16), 'COIL')]}

# %%
if __name__ ==  '__main__':
    for i in range(n_jobs):
    #for i in range(0,1):
        tic = time.time()
        with Pool(n_workers) as pool:
            results = [pool.apply_async(plot_orginial_channel_dist_vs_transform, p) for p in jobs[i]]

            print("Starting job {}/{}".format(i+1, n_jobs))
            for r in results:
                r.get()
        print('Job completed in {} mins'.format(round((time.time() - tic)/60)))
        del(jobs[i])
        del(pool)
# Out:
# Starting job 1/9
# Job completed in 21 mins
# Starting job 2/9
# Job completed in 22 mins
# Starting job 3/9
# Job completed in 21 mins
# Starting job 4/9
# Job completed in 21 mins
# Starting job 5/9
# Job completed in 23 mins
# Starting job 6/9
# <ipython-input-6-ed8e7af97226>:39: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(1,n_columns, figsize=figsize)
# <ipython-input-6-ed8e7af97226>:39: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(1,n_columns, figsize=figsize)
# <ipython-input-6-ed8e7af97226>:39: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(1,n_columns, figsize=figsize)
# <ipython-input-6-ed8e7af97226>:39: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(1,n_columns, figsize=figsize)
# Job completed in 21 mins
# Starting job 7/9
# Job completed in 23 mins
# Starting job 8/9
# Job completed in 21 mins
# Starting job 9/9
# Job completed in 14 mins
