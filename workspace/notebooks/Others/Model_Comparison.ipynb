# %%
import pandas as pd
import numpy as np
# To display all the columns
pd.options.display.max_columns = None
import os
import json
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
# Preprocessed data path
pp_path = '/home/hhughes/Documents/Master_Thesis/Project/datasets/184A1_hannah_avg_projection_splited'
os.listdir(pp_path)
# Out:
# ['params.json', 'channels.csv', 'metadata.csv']

# %%
with open(os.path.join(pp_path, 'metadata.csv')) as file:
    metadata = pd.read_csv(file)
    
with open(os.path.join(pp_path, 'channels.csv')) as file:
    channels = pd.read_csv(file)

with open(os.path.join(pp_path, 'params.json')) as file:
    pp = json.load(file)
pp.keys()
# Out:
# dict_keys(['_comment', 'raw_data_dir', 'dir_type', 'perturbations_and_wells', 'external_libs_path', 'output_data_dir', 'seed', 'input_channels', 'output_channels', 'aggregate_output', 'train_frac', 'val_frac', 'img_size', 'subtract_background', 'background_value', 'normalise', 'percentile', 'add_cell_cycle_to_metadata', 'cell_cycle_file', 'add_well_info_to_metadata', 'well_info_file', 'filter_criteria', 'filter_values', 'convert_into_image', 'remove_original_data', 'project_into_scalar', 'method', 'log_file', 'log_level', 'data_dirs', 'normalise_rescale_values', 'normalise_rescale_values_scalars', 'output_files'])

# %%
# Add normalization values to channel df
channels['normalization_val'] = pp['normalise_rescale_values_scalars']
channels.drop(['Unnamed: 0'], axis=1, inplace=True)
channels
# Out:
#     channel_id               name  normalization_val
# 0            0            00_DAPI          56.132246
# 1            1             07_H2B         274.264162
# 2            2      01_CDK9_pT186          21.499582
# 3            3            03_CDK9          46.196136
# 4            4           05_GTF2B         126.727922
# 5            5          07_SETD1A          42.536269
# 6            6         08_H3K4me3          64.211107
# 7            7           09_SRRM2          73.813698
# 8            8         10_H3K27ac         292.815155
# 9            9       11_KPNA2_MAX         103.422563
# 10          10  12_RB1_pS807_S811         139.336457
# 11          11          13_PABPN1         220.117563
# 12          12            14_PCNA         102.879176
# 13          13             15_SON          56.731151
# 14          14              16_H3         366.687076
# 15          15           17_HDAC3         110.999019
# 16          16       19_KPNA1_MAX         127.070598
# 17          17           20_SP100          36.656249
# 18          18             21_NCL          71.600491
# 19          19          01_PABPC1          31.954935
# 20          20            02_CDK7         168.903589
# 21          21            03_RPS6          31.972639
# 22          22              05_Sm          66.619599
# 23          23          07_POLR2A         179.786532
# 24          24           09_CCNT1         125.706105
# 25          25      10_POL2RA_pS2         314.542672
# 26          26             11_PML          21.369446
# 27          27            12_YAP1         171.796065
# 28          28      13_POL2RA_pS5         314.516135
# 29          29        15_U2SNRNPB          62.048017
# 30          30            18_NONO         386.614464
# 31          31          20_ALYREF         427.114179
# 32          32            21_COIL          11.630801
# 33          33           00_BG488           8.915866
# 34          34           00_BG568           1.870817
# 35          35              00_EU         471.615792
# 36          36   09_SRRM2_ILASTIK       10052.321134
# 37          37     15_SON_ILASTIK       13317.137935

# %%
metadata
# Out:
#        Unnamed: 0  mapobject_id plate_name well_name  well_pos_y  well_pos_x  \
# 0               0        369581    plate01       I18           0           0
# 1               1        369583    plate01       I18           0           0
# 2               2        369584    plate01       I18           0           0
# 3               3        369585    plate01       I18           0           0
# 4               4        369586    plate01       I18           0           0
# ...           ...           ...        ...       ...         ...         ...
# 13095       13095        196980    plate01       J12           5           3
# 13096       13096        266544    plate01       J12           5           4
# 13097       13097        266556    plate01       J12           5           4
# 13098       13098        266561    plate01       J12           5           4
# 13099       13099        266565    plate01       J12           5           4
#
#        tpoint  zplane  label  is_border  mapobject_id_cell plate_name_cell  \
# 0           0       0      9          0             369487         plate01
# 1           0       0     11          0             369489         plate01
# 2           0       0     12          0             369490         plate01
# 3           0       0     13          0             369491         plate01
# 4           0       0     14          0             369492         plate01
# ...       ...     ...    ...        ...                ...             ...
# 13095       0       0     16          0             196946         plate01
# 13096       0       0     23          0             266495         plate01
# 13097       0       0     35          0             266507         plate01
# 13098       0       0     40          0             266512         plate01
# 13099       0       0     44          0             266516         plate01
#
#       well_name_cell  well_pos_y_cell  well_pos_x_cell  tpoint_cell  \
# 0                I18                0                0            0
# 1                I18                0                0            0
# 2                I18                0                0            0
# 3                I18                0                0            0
# 4                I18                0                0            0
# ...              ...              ...              ...          ...
# 13095            J12                5                3            0
# 13096            J12                5                4            0
# 13097            J12                5                4            0
# 13098            J12                5                4            0
# 13099            J12                5                4            0
#
#        zplane_cell  label_cell  is_border_cell  is_mitotic  is_mitotic_labels  \
# 0                0           9               0         0.0                NaN
# 1                0          11               0         0.0                NaN
# 2                0          12               0         0.0                NaN
# 3                0          13               0         0.0                NaN
# 4                0          14               0         0.0                NaN
# ...            ...         ...             ...         ...                ...
# 13095            0          16               0         0.0                NaN
# 13096            0          23               0         0.0                NaN
# 13097            0          35               0         0.0                NaN
# 13098            0          40               0         0.0                NaN
# 13099            0          44               0         0.0                NaN
#
#        is_polynuclei_HeLa  is_polynuclei_HeLa_labels  is_polynuclei_184A1  \
# 0                     0.0                        NaN                  0.0
# 1                     0.0                        NaN                  0.0
# 2                     0.0                        NaN                  0.0
# 3                     0.0                        NaN                  0.0
# 4                     0.0                        NaN                  0.0
# ...                   ...                        ...                  ...
# 13095                 0.0                        NaN                  0.0
# 13096                 0.0                        NaN                  0.0
# 13097                 0.0                        NaN                  0.0
# 13098                 0.0                        NaN                  0.0
# 13099                 0.0                        NaN                  0.0
#
#        is_polynuclei_184A1_labels cell_cycle cell_type perturbation  duration  \
# 0                             NaN          S     184A1       CX5461     120.0
# 1                             NaN         G1     184A1       CX5461     120.0
# 2                             NaN         G1     184A1       CX5461     120.0
# 3                             NaN          S     184A1       CX5461     120.0
# 4                             NaN         G1     184A1       CX5461     120.0
# ...                           ...        ...       ...          ...       ...
# 13095                         NaN          S     184A1       normal       NaN
# 13096                         NaN          S     184A1       normal       NaN
# 13097                         NaN          S     184A1       normal       NaN
# 13098                         NaN         G1     184A1       normal       NaN
# 13099                         NaN         G2     184A1       normal       NaN
#
#        00_DAPI_avg  07_H2B_avg  01_CDK9_pT186_avg  03_CDK9_avg  05_GTF2B_avg  \
# 0         0.797954    0.760859           0.742445     0.634022      0.663027
# 1         0.723802    0.817599           0.552732     0.545909      0.700967
# 2         0.840696    0.929793           0.407526     0.486692      0.682011
# 3         0.794479    0.567609           1.046119     0.739995      0.934936
# 4         0.550997    0.608366           0.253561     0.166947      0.445885
# ...            ...         ...                ...          ...           ...
# 13095     0.466116    0.427223           0.524259     0.559983      0.778531
# 13096     0.637199    0.383999           0.418047     0.527632      0.613568
# 13097     0.579194    0.412988           0.381970     0.441706      0.496858
# 13098     0.481913    0.481001           0.408701     0.438119      0.750543
# 13099     0.694338    0.277279           0.816941     0.783287      0.821891
#
#        07_SETD1A_avg  08_H3K4me3_avg  09_SRRM2_avg  10_H3K27ac_avg  \
# 0           0.568395        0.730102      0.686346        0.366674
# 1           0.695602        0.729558      0.731996        0.210496
# 2           0.167238        0.440246      0.686533        0.185236
# 3           1.018996        0.794462      0.794089        0.178088
# 4           0.278494        0.357785      0.432984        0.124483
# ...              ...             ...           ...             ...
# 13095       0.549776        0.643514      0.551811        0.193130
# 13096       0.470998        0.641225      0.419378        0.319716
# 13097       0.335659        0.515844      0.383102        0.285956
# 13098       0.462461        0.598127      0.562935        0.176255
# 13099       0.864460        0.782297      0.541255        0.370834
#
#        11_KPNA2_MAX_avg  12_RB1_pS807_S811_avg  13_PABPN1_avg  14_PCNA_avg  \
# 0              0.575989               0.684307       0.736716     0.732316
# 1              0.457588               0.861228       0.846120     0.567214
# 2              0.378296               0.631725       0.714524     0.305706
# 3              0.757432               0.911557       0.777467     0.732617
# 4              0.247782               0.028756       0.478999     0.229982
# ...                 ...                    ...            ...          ...
# 13095          0.478116               0.712937       0.743597     0.522384
# 13096          0.322750               0.549373       0.583993     0.507319
# 13097          0.334541               0.478602       0.642649     0.590243
# 13098          0.414752               0.821986       0.644833     0.302289
# 13099          0.586427               0.873146       0.867369     0.422775
#
#        15_SON_avg  16_H3_avg  17_HDAC3_avg  19_KPNA1_MAX_avg  20_SP100_avg  \
# 0        0.740041   0.635465      0.678882          0.653309      0.518513
# 1        0.767485   0.717981      0.654874          0.602190      0.712462
# 2        0.509345   0.709603      0.537640          0.524173      0.276606
# 3        0.794341   0.449047      0.704155          0.676932      0.505251
# 4        0.437616   0.478644      0.404991          0.382058      0.324963
# ...           ...        ...           ...               ...           ...
# 13095    0.581592   0.384521      0.480271          0.515179      0.437035
# 13096    0.553977   0.414093      0.429652          0.442965      0.345834
# 13097    0.519747   0.445927      0.466204          0.501111      0.441162
# 13098    0.691286   0.509955      0.497737          0.480673      0.389919
# 13099    0.697940   0.284133      0.733012          0.752142      0.653014
#
#        21_NCL_avg  01_PABPC1_avg  02_CDK7_avg  03_RPS6_avg  05_Sm_avg  \
# 0        0.664592       0.671655     0.709863     0.704627   0.689181
# 1        0.664804       0.565396     0.742811     0.644895   0.787064
# 2        0.669621       0.517582     0.622845     0.632177   0.707219
# 3        0.489204       0.809605     1.337379     0.755681   0.812838
# 4        0.457266       0.362926     0.391432     0.386674   0.504923
# ...           ...            ...          ...          ...        ...
# 13095    0.545412       0.428227     0.565138     0.481548   0.577957
# 13096    0.479689       0.316905     0.423932     0.360906   0.469056
# 13097    0.421151       0.326183     0.351802     0.368628   0.440929
# 13098    0.529000       0.372712     0.573087     0.431294   0.516686
# 13099    0.654303       0.705137     0.631683     0.625659   0.577555
#
#        07_POLR2A_avg  09_CCNT1_avg  10_POL2RA_pS2_avg  11_PML_avg  \
# 0           0.578649      0.640880           0.963868    0.537138
# 1           0.674728      0.644300           0.930544    0.636029
# 2           0.307346      0.463200           0.810092    0.509207
# 3           0.839893      0.896986           0.850779    0.849887
# 4           0.254977      0.204945           0.621206    0.519153
# ...              ...           ...                ...         ...
# 13095       0.520295      0.529232           0.743118    0.569474
# 13096       0.488063      0.413873           0.745399    0.350399
# 13097       0.392850      0.362778           0.626234    0.495860
# 13098       0.474053      0.334629           0.718572    0.518643
# 13099       0.863509      0.795253           0.701192    0.925068
#
#        12_YAP1_avg  13_POL2RA_pS5_avg  15_U2SNRNPB_avg  18_NONO_avg  \
# 0         0.541909           0.705251         0.628631     0.742686
# 1         0.651211           0.705137         0.637545     0.862667
# 2         0.573902           0.785905         0.602015     0.843908
# 3         0.896995           0.584139         0.764801     0.749374
# 4         0.368919           0.519851         0.419770     0.546952
# ...            ...                ...              ...          ...
# 13095     0.409859           0.606166         0.481509     0.666436
# 13096     0.184317           0.526459         0.397377     0.511406
# 13097     0.277251           0.535496         0.378879     0.555842
# 13098     0.276903           0.637072         0.440410     0.698329
# 13099     0.584791           0.474696         0.788823     0.457983
#
#        20_ALYREF_avg  21_COIL_avg  00_BG488_avg  00_BG568_avg  00_EU_avg  \
# 0           0.624242     0.675802      0.691226      0.893528   0.727097
# 1           0.726507     0.765920      0.681950      0.827772   0.413577
# 2           0.678252     0.630470      0.658251      0.830965   0.408940
# 3           0.491297     0.856009      0.824890      0.906335   0.571464
# 4           0.507730     0.462206      0.525616      0.836503   0.344327
# ...              ...          ...           ...           ...        ...
# 13095       0.509698     0.621739      0.579675      0.892434   0.762380
# 13096       0.452926     0.454194      0.431128      0.788293   0.796441
# 13097       0.478219     0.447294      0.443448      0.836235   0.671556
# 13098       0.557219     0.568876      0.449033      0.835750   0.848631
# 13099       0.414009     0.694694      0.655231      0.948463   0.962662
#
#        09_SRRM2_ILASTIK_avg  15_SON_ILASTIK_avg    set
# 0                  0.778933            0.773748  train
# 1                  0.617883            0.758037  train
# 2                  0.674905            0.589623  train
# 3                  0.785784            0.732261  train
# 4                  0.534069            0.564822  train
# ...                     ...                 ...    ...
# 13095              0.589774            0.685176   test
# 13096              0.416512            0.659525   test
# 13097              0.441012            0.683489   test
# 13098              0.726809            0.790168   test
# 13099              0.606503            0.678118   test
#
# [13100 rows x 68 columns]

# %%
# Create masks for train, val, cv (cv = train + val) and test
mask_train = (metadata['set'] == 'train')
mask_val = (metadata['set'] == 'val')
mask_cv = mask_train | mask_val
mask_test = (metadata['set'] == 'test')

# %%
x_columns = [c+'_'+pp['method'] for c in pp['input_channels']]
# Discriminate channels: 
drop_cols = ['00_BG488_avg', '00_BG568_avg', '09_SRRM2_ILASTIK_avg', '15_SON_ILASTIK_avg']
x_columns = [c for c in x_columns if not c in drop_cols]

# Create dfs
X = metadata[x_columns].copy()
# Remove projection method from name
channel_columns = [c[:-(len(pp['method'])+1)] for c in X.columns]
X.columns = channel_columns
# Add perturbation to X
X['perturbation'] = metadata['perturbation']
# Convert perturbation to a binary var
perturbations = list(np.unique(metadata[['perturbation']].values))
perturbations.remove('normal')
for per in perturbations:
    mask = (X['perturbation'] == per)
    X['per_'+per] = mask
X = X.drop(['perturbation'], axis=1)
#X

# %%
y_columns = pp['output_channels'][0]+'_'+pp['method'] 
Y = pd.DataFrame(metadata[y_columns])
Y.columns = [pp['output_channels'][0]]
# Revert normalization of target var
y_norm_val = channels.set_index('name').loc[pp['output_channels']].normalization_val.values[0]
Y = Y * y_norm_val
#Y

# %%
# Metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer
from sklearn.preprocessing import PolynomialFeatures

# Define score
r2 = make_scorer(r2_score, greater_is_better=True)

per_order = ['AZD4573', 'Meayamycin', 'Triptolide', 'CX5461',  'TSA', 'DMSO', 'normal']

def plot_y_vs_y_hat(df, y_hat):
    
    # Create df with perturbations
    per_df = metadata[['mapobject_id_cell', 'perturbation']]
    temp_df = df.merge(
        per_df, 
        left_on='mapobject_id_cell',
        right_on='mapobject_id_cell',
        how='left',
    )

    sns.scatterplot(data=temp_df,
                    x='y',
                    y=y_hat,
                    hue='perturbation',
                    hue_order=per_order,
                    #s=15,
                    alpha=0.5)
    plt.axis('equal')

    min_val = df[['y', y_hat]].min().values.min()
    max_val = df[['y', y_hat]].max().values.min()

    x_line = [min_val, max_val]
    y_line = x_line
    plt.plot(x_line, y_line, linestyle='dashed', color='red')
    plt.title(y_hat)

def plot_residuals(df, y_hat):
    
    # Create df with perturbations
    per_df = metadata[['mapobject_id_cell', 'perturbation']]
    temp_df = df.merge(
        per_df, 
        left_on='mapobject_id_cell',
        right_on='mapobject_id_cell',
        how='left',
    )
    
    temp_df['diff'] = temp_df['y'] - temp_df[y_hat]
    std = temp_df['diff'].std()
    temp_df['std_residuals'] = temp_df['diff'] / std
    
    sns.scatterplot(
        data=temp_df,
        x = 'y',
        y = 'std_residuals',
        hue = 'perturbation',
        hue_order=per_order,
    )
    plt.hlines(y=2, xmin=np.min(temp_df['y']), xmax=np.max(temp_df['y']), color='red', ls='dashed')
    plt.hlines(y=-2, xmin=np.min(temp_df['y']), xmax=np.max(temp_df['y']), color='red', ls='dashed')
    plt.title(y_hat)

def plot_error_dist(df, y_models):
    temp_df = df.copy()
    
    # Add perturbations to df
    per_df = metadata[['mapobject_id_cell', 'perturbation']]
    temp_df = temp_df.merge(
        per_df, 
        left_on='mapobject_id_cell',
        right_on='mapobject_id_cell',
        how='left',
    )
    
    diff_names = ['set', 'perturbation']
    for y_model in y_models:
        # Column name for difference between y and y_model
        col_name = 'y - '+y_model
        diff_names.append(col_name)
        temp_df[col_name] = temp_df['y'] - temp_df[y_model]
        
    temp_df = temp_df[diff_names].set_index(['set', 'perturbation'])
    temp_df = temp_df.stack().reset_index()
    #temp_df = temp_df.drop(['level_0'], axis=1)
    temp_df.columns = ['set', 'perturbation'] + ['diff_name', 'value']
    
    plt.figure(figsize=(20,7))
    sns.kdeplot(x='value',
                #common_norm=True,
                data=temp_df,
                hue='diff_name',
                #hue_order=order,
                #color=colors,
                shade=True, 
                bw_method=0.2)

    plt.vlines(x=0, ymin=0, ymax=0.003, color='red', ls='dashed')
    plt.xlabel('y - y_hat')
    plt.title('Error KDE per model')
    
    plt.figure(figsize=(20,7))
    sns.boxplot(y='value',
                x='diff_name',
                hue='perturbation',
                hue_order=per_order,
                data=temp_df)
    plt.xlabel('Diff Name')
    plt.ylabel('y - y_hat')
    plt.title('Error Distribution per set')
    
# Add metrics to metrics df
def calculate_and_save_metric_vals(df, y_model, k):
    # Create df to store metrics to compare models
    metric_columns = ['model', 'set', 'R2', 'BIC', 'MSE', 'MAE']
    temp_df = pd.DataFrame(columns=metric_columns)
    
    sets = ['train', 'val', 'test']
    for ss in sets:
        mask = (metadata['set'] == ss)
        y = df['y'][mask].values
        #print(y.shape)
        #print(df['y_Poly_Lasso'].shape)
        y_hat = df[y_model][mask].values
        
        r2 = round(r2_score(y, y_hat),4)
        bic = round(get_BIC(y=y, y_hat=y_hat, k=k),4)
        mse = round(mean_squared_error(y, y_hat),4)
        mae = round(mean_absolute_error(y, y_hat),4)
        temp_df = temp_df.append({'model':y_model[2:], 'set':ss, 'R2':r2, 'BIC':bic, 'MSE':mse, 'MAE':mae}, ignore_index=True)
    
    return temp_df

def get_BIC(y, y_hat, k):
    SS_residual = np.sum((y-y_hat)**2)
    n = y.shape[0]
    return n * np.log(SS_residual / n) + np.log(n) * k
    
def get_polynomial_dataset(X_array=None, X_array_names=None, degree=1, interaction_only=False):
    # Init the pipeline to create the dataset 
    poly_trans = PolynomialFeatures(degree=degree, interaction_only=interaction_only, include_bias=False)
    # Create the dataset
    X_temp = poly_trans.fit_transform(X_array)
    # Get the interactions names
    X_temp_names = poly_trans.get_feature_names(X_array_names)
    
    # Create a mask that will exclude the unwanted interactions
    mask_interactions = np.ones(len(X_temp_names))
    for i, inter_name in enumerate(X_temp_names):
        # Detect which interection have a perturbation
        if 'per_' in inter_name:
            # for each of the perturbations detect if one has per_ and ^
            for var in inter_name.split(" "):
                if ('per_' in var) and ('^' in var):
                    mask_interactions[i] = 0
    mask_interactions = mask_interactions.astype(np.bool)

    # Filter X_temp
    X_temp = X_temp[:,mask_interactions]
    X_temp_names = list(np.asarray(X_temp_names)[mask_interactions])
    
    return X_temp, X_temp_names

def plot_coef(df, x_name='coef', y_name='var_name'):
    temp_df = df.sort_values(by=[x_name], ascending=False)
    plt.figure(figsize=(15,20))
    sns.barplot(
        data=temp_df,
        x=x_name,
        y=y_name,
        orient="h",
        palette="viridis"
        )

# %% [markdown]
# ### Plot distribution of variables

# %%
# Plot data distribution
temp_df = X[channel_columns].copy()
temp_df = temp_df.stack().reset_index()
temp_df = temp_df.drop(['level_0'], axis=1)
temp_df.columns = ['channel', 'value']
#temp_df['channel'] = [c[:-(len(pp['method'])+1)] for c in temp_df['channel'].values]
temp_df

plt.figure(figsize=(15,7))
sns.boxplot(data=temp_df,
            x='channel',
            y='value')
_,_ = plt.xticks(rotation=90)

plt.figure(figsize=(15,7))
sns.violinplot(data=temp_df,
            x='channel',
            y='value')
_,_ = plt.xticks(rotation=90)

plt.figure(figsize=(5,7))
sns.violinplot(data=Y,
            y='00_EU')
#sns.swarmplot(data=Y,
#             y='00_EU')
# Out:
# <AxesSubplot:ylabel='00_EU'>

# %% [markdown]
# ## Load linear models results

# %%
# Load results
linear_models_path = '/home/hhughes/Documents/Master_Thesis/Project/workspace/models/Linear_models'

# Load files
with open(os.path.join(linear_models_path, 'Predictions.csv'), 'r') as file:
    lm_predictions_df = pd.read_csv(file)

with open(os.path.join(linear_models_path, 'Metric_vals.csv'), 'r') as file:
    metric_vals_df = pd.read_csv(file)

with open(os.path.join(linear_models_path, 'Coefficients.csv'), 'r') as file:
    coef_df = pd.read_csv(file)
    
with open(os.path.join(linear_models_path, 'Coefficients_poly_lasso_d2.csv'), 'r') as file:
    poly_lasso_coef_df_d2 = pd.read_csv(file)

with open(os.path.join(linear_models_path, 'Coefficients_poly_lasso_d3.csv'), 'r') as file:
    poly_lasso_coef_df_d2 = pd.read_csv(file)

# %% [markdown]
# ## Load CNN models results

# %%
# Baseline CNN with data augmentation
temp_path = '/home/hhughes/Documents/Master_Thesis/Project/workspace/models/All_dataset/baseline_CNN/With_Data_Augm/'
with open(os.path.join(temp_path, 'targets.csv'), 'r') as file:
    temp_df = pd.read_csv(file)
    temp_df = temp_df.drop(['Unnamed: 0'], axis=1)
    temp_df.columns = ['y', 'y_BL_w_a', 'mapobject_id_cell', 'set']

# %%
predictions_df = lm_predictions_df.merge(
        temp_df[['mapobject_id_cell', 'y_BL_w_a']], 
        left_on='mapobject_id_cell',
        right_on='mapobject_id_cell',
        how='left',
    )

# %%
# ResNet50V2 with data augmentation
temp_path = '/home/hhughes/Documents/Master_Thesis/Project/workspace/models/All_dataset/ResNet50V2/With_Data_Augm'
with open(os.path.join(temp_path, 'targets.csv'), 'r') as file:
    temp_df = pd.read_csv(file)
    temp_df = temp_df.drop(['Unnamed: 0'], axis=1)
    temp_df.columns = ['y', 'y_RN50v2', 'mapobject_id_cell', 'set']

# %%
predictions_df = predictions_df.merge(
        temp_df[['mapobject_id_cell', 'y_RN50v2']], 
        left_on='mapobject_id_cell',
        right_on='mapobject_id_cell',
        how='left',
    )

# %%
# pretrained ResNet50V2 with data augmentation
temp_path = '/home/hhughes/Documents/Master_Thesis/Project/workspace/models/All_dataset/ResNet50V2_PreTrained/PreTreined_w_Data_Augm'
with open(os.path.join(temp_path, 'targets.csv'), 'r') as file:
    temp_df = pd.read_csv(file)
    temp_df = temp_df.drop(['Unnamed: 0'], axis=1)
    temp_df.columns = ['y', 'y_PreTrain_RN50v2', 'mapobject_id_cell', 'set']
    
predictions_df = predictions_df.merge(
        temp_df[['mapobject_id_cell', 'y_PreTrain_RN50v2']], 
        left_on='mapobject_id_cell',
        right_on='mapobject_id_cell',
        how='left',
    )

# %%
# identify duplicated values
mask = predictions_df['mapobject_id_cell'].duplicated()
duplicated_ids = np.unique(predictions_df[mask]['mapobject_id_cell'].values)

# %%
mask = np.zeros(predictions_df.shape[0])
for i, cell_id in enumerate(predictions_df['mapobject_id_cell'].values):
    if cell_id in duplicated_ids:
        mask[i] = 1
mask = mask.astype(np.bool)

duplicated_df = predictions_df[mask].sort_values(by=['mapobject_id_cell'])
print('Number of total duplicated: {}'.format(duplicated_df.shape[0]))
n_dup_train = duplicated_df[duplicated_df['set'] == 'train'].shape[0]
print(n_dup_train)
n_dup_val = duplicated_df[duplicated_df['set'] == 'val'].shape[0]
print(n_dup_val)
n_dup_test = duplicated_df[duplicated_df['set'] == 'test'].shape[0]
print(n_dup_test)
print(n_dup_train+n_dup_val+n_dup_test)
# Out:
# Number of total duplicated: 2380
# 1902
# 236
# 242
# 2380

# %% [markdown]
# Create a DataFrame that will contain the predictions of all the models:

# %%
predictions_df
# Out:
#        mapobject_id_cell    set           y       y_ols  y_ols_no_indi  \
# 0                 369487  train  342.910464  318.025463     361.922994
# 1                 369489  train  195.049564  284.870365     326.175742
# 2                 369490  train  192.862674  267.554810     292.086822
# 3                 369491  train  269.511643  322.633323     360.762642
# 4                 369492  train  162.390196  233.673499     251.054669
# ...                  ...    ...         ...         ...            ...
# 13095             196946   test  359.550328  376.279688     371.722119
# 13096             266495   test  375.614026  370.760456     357.585782
# 13097             266507   test  316.716326  351.509466     328.351303
# 13098             266512   test  400.227596  365.611902     367.108247
# 13099             266516   test  454.006752  398.886786     376.137392
#
#         y_elastic     y_ridge     y_Lasso  y_Poly_Lasso_d2  y_Poly_Lasso_d3  \
# 0      317.478414  317.989772  317.478414       324.854407       327.138380
# 1      286.457888  285.948562  286.457888       292.639252       292.202916
# 2      268.393229  266.014380  268.393229       262.754232       263.530109
# 3      324.009534  323.727438  324.009534       322.484937       315.453591
# 4      233.293969  232.277269  233.293969       237.603645       237.301899
# ...           ...         ...         ...              ...              ...
# 13095  376.107837  375.862581  376.107837       372.270596       369.958164
# 13096  370.341508  369.260781  370.341508       362.051731       360.313743
# 13097  350.279401  348.385496  350.279401       329.352897       326.386724
# 13098  365.388126  365.475612  365.388126       356.189827       354.575014
# 13099  396.396834  393.325583  396.396834       392.178547       391.375183
#
#          y_RN50v2
# 0      325.902557
# 1      275.954834
# 2      260.037811
# 3      292.958344
# 4      215.635254
# ...           ...
# 13095  399.028687
# 13096  378.137604
# 13097  328.137817
# 13098  384.014374
# 13099  441.581177
#
# [13100 rows x 11 columns]

# %%
y_models = ['y_ols_no_indi', 'y_ols', 'y_elastic', 'y_ridge', 'y_Lasso', 'y_Poly_Lasso_d2','y_Poly_Lasso_d3', 'y_BL_w_a', 'y_RN50v2', 'y_PreTrain_RN50v2']

min_val = int(np.round(np.min(predictions_df[['y']+y_models].min().values))) - 5
max_val = int(np.round(np.max(predictions_df[['y']+y_models].max().values))) + 5

# %%
# Plot predictions
plt.figure(figsize=(len(y_models)*8,7))
for i, y_hat in enumerate(y_models, 1):
    plt.subplot(1, len(y_models), i)
    plot_y_vs_y_hat(df=predictions_df[mask_cv], y_hat=y_hat)
    plt.xlim([min_val, max_val])
    plt.ylim([min_val, max_val])

# %%
# Plot residuals
plt.figure(figsize=(len(y_models)*10,7))
for i, y_hat in enumerate(y_models, 1):
    plt.subplot(1, len(y_models), i)
    plot_residuals(df=predictions_df[mask_cv], y_hat=y_hat)
    #plt.xlim([min_val, max_val])
    plt.ylim([-10, 10])

# %%
def calculate_and_save_metric_vals(df, y_model, k):
    # Create df to store metrics to compare models
    metric_columns = ['model', 'set', 'R2', 'BIC', 'MSE', 'MAE']
    temp_df = pd.DataFrame(columns=metric_columns)
    
    sets = ['train', 'val', 'test']
    for ss in sets:
        mask = (metadata['set'] == ss)
        y = df['y'][mask].values
        #print(y.shape)
        #print(df['y_Poly_Lasso'].shape)
        y_hat = df[y_model][mask].values
        
        r2 = round(r2_score(y, y_hat),4)
        bic = round(get_BIC(y=y, y_hat=y_hat, k=k),4)
        mse = round(mean_squared_error(y, y_hat),4)
        mae = round(mean_absolute_error(y, y_hat),4)
        temp_df = temp_df.append({'model':y_model[2:], 'set':ss, 'R2':r2, 'BIC':bic, 'MSE':mse, 'MAE':mae}, ignore_index=True)
    
    return temp_df

# %%
calculate_and_save_metric_vals(predictions_df, 'y_BL_w_a', 1000)
# Out:
#     model    set      R2         BIC        MSE      MAE
# 0  BL_w_a  train  0.8943  81624.7064  1004.2343  22.2658
# 1  BL_w_a    val  0.8849  16296.2376  1112.2095  23.1563
# 2  BL_w_a   test  0.8871  16465.4781  1072.3947  23.0642

# %%
# Depper look into error distribution per model
plot_error_dist(predictions_df[mask_cv], y_models)

# %%
metric_vals_df
# Out:
#             model    set      R2         BIC        MSE      MAE
# 0     ols_no_indi  train  0.8188  78324.3005  1721.1921  31.2837
# 1     ols_no_indi    val  0.8150   9986.5676  1787.6698  31.4532
# 2     ols_no_indi   test  0.8259  10092.9312  1653.0568  31.0243
# 3         elastic  train  0.8803  74001.1168  1136.9366  24.0304
# 4         elastic    val  0.8846   9386.6410  1114.8970  24.0239
# 5         elastic   test  0.8836   9572.8396  1105.6818  24.0689
# 6           ridge  train  0.8802  74044.0892  1137.5826  24.0763
# 7           ridge    val  0.8836   9426.7120  1124.6983  24.1412
# 8           ridge   test  0.8830   9608.5570  1111.4781  24.1672
# 9           Lasso  train  0.8803  74001.1168  1136.9366  24.0304
# 10          Lasso    val  0.8846   9386.6410  1114.8970  24.0239
# 11          Lasso   test  0.8836   9572.8396  1105.6818  24.0689
# 12  Poly_Lasso_d2  train  0.8921  73057.4117  1024.3498  22.2412
# 13  Poly_Lasso_d2    val  0.8976   9345.4199   988.9501  22.3162
# 14  Poly_Lasso_d2   test  0.8930   9576.0460  1016.4206  22.4142
# 15  Poly_Lasso_d3  train  0.8946  72989.6329  1000.7873  22.0128
# 16  Poly_Lasso_d3    val  0.9009   9439.5857   957.4742  22.0264
# 17  Poly_Lasso_d3   test  0.8946   9691.8172  1000.5762  22.2305

# %% [markdown]
# ## OLS

# %%
# Create and fit lm
ols_model = lm.LinearRegression(n_jobs=6).fit(X[mask_train].values, Y[mask_train].values)

# %%
# Create df that will contain all the coefficients
values = np.append(ols_model.intercept_, ols_model.coef_)
coef_df = pd.DataFrame(np.round(values,4))
coef_df['Variable'] = ['intercept'] + list(X.columns)
coef_df.columns = ['ols', 'Variable']

# %%
# Add predictions to df
predictions_df['y_ols'] = ols_model.predict(X.values)

# %%
# Get number of predictors
k = sum(coef_df['ols'] != 0)
temp_metrics_df = calculate_and_save_metric_vals(df=predictions_df, y_model='y_ols', k=k)
metric_vals_df = temp_metrics_df

# %%
#plot_coef(df=coef_df, x_name='ols', y_name='Variable')

# %% [markdown]
# ## OLS (with no perturbation indication vars)

# %%
# Create and fit lm
ols_model_no_indi = lm.LinearRegression(n_jobs=6).fit(X[channel_columns][mask_train].values, Y[mask_train].values)

# %%
# Add coefficients to coef df
values = np.round(np.concatenate((ols_model_no_indi.intercept_, ols_model_no_indi.coef_.reshape(-1), np.zeros(len(perturbations))), axis=0), 4)
coef_df['ols_no_indi'] = values

# %%
# Add predictions to df
predictions_df['y_ols_no_indi'] = ols_model_no_indi.predict(X[channel_columns].values)

# %%
# Get number of predictors
k = sum(coef_df['ols_no_indi'] != 0)
temp_metrics_df = calculate_and_save_metric_vals(df=predictions_df, y_model='y_ols_no_indi', k=k)
metric_vals_df = temp_metrics_df

# %%
#plot_coef(df=coef_df, x_name='ols_no_indi', y_name='Variable')

# %% [markdown]
# ## Linear regression with Regularization
#
# For regularization method we use cross validation to approximate the best hyperparameters.

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### ElasticNet

# %%
enet = lm.ElasticNet()
params_enet = {'alpha':np.arange(0.001, 0.1, 0.001), 
               'l1_ratio':np.arange(0.05, 1.05, 0.05), 
               'normalize':[False]}
enet_grid = GridSearchCV(enet, params_enet, scoring = r2, cv=5)

# %%
# Fit ElasticNet 
enet_grid.fit(X[mask_cv].values, Y[mask_cv].values)
# Out:
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': array([0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009,
#        0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017, 0.018,
#        0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026, 0.027,
#        0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035, 0.036,
#        0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044, 0.045,
#        0.046, 0.047, 0.04...
#        0.064, 0.065, 0.066, 0.067, 0.068, 0.069, 0.07 , 0.071, 0.072,
#        0.073, 0.074, 0.075, 0.076, 0.077, 0.078, 0.079, 0.08 , 0.081,
#        0.082, 0.083, 0.084, 0.085, 0.086, 0.087, 0.088, 0.089, 0.09 ,
#        0.091, 0.092, 0.093, 0.094, 0.095, 0.096, 0.097, 0.098, 0.099]),
#                          'l1_ratio': array([0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55,
#        0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#                          'normalize': [False]},
#              scoring=make_scorer(r2_score))

# %%
# Print best hyperparameters
enet_grid.best_estimator_
# Out:
# ElasticNet(alpha=0.02, l1_ratio=1.0)

# %%
# Add coefficients to coef df
values = np.round(np.append(enet_grid.best_estimator_.intercept_, enet_grid.best_estimator_.coef_), 4)
coef_df['Elastic'] = values

# %%
# Save fitted values
predictions_df['y_elastic'] = enet_grid.best_estimator_.predict(X.values)

# %%
# Get number of predictors
k = sum(coef_df['Elastic'] != 0)
# Get and save metrics values for this model
temp_metrics_df = calculate_and_save_metric_vals(df=predictions_df, y_model='y_elastic', k=k)
metric_vals_df = metric_vals_df.append(temp_metrics_df, ignore_index=True)

# %%
#plot_coef(df=coef_df, x_name='Elastic', y_name='Variable')

# %% [markdown]
# ### Ridge

# %%
ridge = lm.Ridge()
params_rige = {'alpha':np.arange(0.009, 0.02, 0.001), 'normalize':[True]}
ridge_grid = GridSearchCV(ridge, params_rige, scoring=r2, cv=5)

# %%
# Fit Ridge 
ridge_grid.fit(X[mask_cv].values, Y[mask_cv].values)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': array([0.009, 0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017,
#        0.018, 0.019]),
#                          'normalize': [True]},
#              scoring=make_scorer(r2_score))

# %%
ridge_grid.best_estimator_
# Out:
# Ridge(alpha=0.009, normalize=True)

# %%
# Add coefficients to coef df
values = np.round(np.append(ridge_grid.best_estimator_.intercept_, ridge_grid.best_estimator_.coef_), 4)
coef_df['Ridge'] = values

# %%
# Save fitted values
predictions_df['y_ridge'] = ridge_grid.best_estimator_.predict(X.values)

# %%
# Get number of predictors
k = sum(coef_df['Ridge'] != 0)
# Get and save metrics values for this model
temp_metrics_df = calculate_and_save_metric_vals(df=predictions_df, y_model='y_ridge', k=k)
metric_vals_df = metric_vals_df.append(temp_metrics_df, ignore_index=True)

# %%
#plot_coef(df=coef_df, x_name='Ridge', y_name='Variable')

# %% [markdown]
# ### Lasso

# %%
lasso = lm.Lasso()
#params_lasso = {'alpha':np.arange(1e-6, 1e-5, 1e-6), 'normalize':[False]}
params_lasso = {'alpha':np.arange(0.001, 0.1, 0.001), 'normalize':[False]}
lasso_grid = GridSearchCV(lasso, params_lasso, scoring=r2, cv=5)

# %%
# Fit Lasso 
lasso_grid.fit(X[mask_cv].values, Y[mask_cv].values)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': array([0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009,
#        0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017, 0.018,
#        0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026, 0.027,
#        0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035, 0.036,
#        0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044, 0.045,
#        0.046, 0.047, 0.048, 0.049, 0.05 , 0.051, 0.052, 0.053, 0.054,
#        0.055, 0.056, 0.057, 0.058, 0.059, 0.06 , 0.061, 0.062, 0.063,
#        0.064, 0.065, 0.066, 0.067, 0.068, 0.069, 0.07 , 0.071, 0.072,
#        0.073, 0.074, 0.075, 0.076, 0.077, 0.078, 0.079, 0.08 , 0.081,
#        0.082, 0.083, 0.084, 0.085, 0.086, 0.087, 0.088, 0.089, 0.09 ,
#        0.091, 0.092, 0.093, 0.094, 0.095, 0.096, 0.097, 0.098, 0.099]),
#                          'normalize': [False]},
#              scoring=make_scorer(r2_score))

# %%
lasso_grid.best_estimator_
# Out:
# Lasso(alpha=0.02)

# %%
# Add coefficients to coef df
values = np.round(np.append(lasso_grid.best_estimator_.intercept_, lasso_grid.best_estimator_.coef_), 4)
coef_df['Lasso'] = values

# %%
# Save fitted values
predictions_df['y_Lasso'] = lasso_grid.best_estimator_.predict(X.values)

# %%
# Get number of predictors
k = sum(coef_df['Lasso'] != 0)
# Get and save metrics values for this model
temp_metrics_df = calculate_and_save_metric_vals(df=predictions_df, y_model='y_Lasso', k=k)
metric_vals_df = metric_vals_df.append(temp_metrics_df, ignore_index=True)

# %%
#plot_coef(df=coef_df, x_name='Lasso', y_name='Variable')

# %% [markdown]
# ### Coefficient Analysis

# %%
#order = ['ols', 'ols_no_indi', 'Ridge', 'Elastic', 'Lasso']
order = ['ols', 'Ridge', 'Elastic', 'Lasso']

temp_df = coef_df[['Variable']+order].copy()
temp_df = temp_df.set_index('Variable').stack().reset_index()
temp_df.columns = ['variable', 'method', 'value']
temp_df = temp_df.sort_values(by=['value'], ascending=False)


plt.figure(figsize=(15,20))
sns.barplot(
    data=temp_df,
    #data=temp_df[temp_df['method'] == 'Lasso'],
    x="value",
    y="variable",
    hue="method",
    hue_order=order,
    orient="h",
    #palette="viridis"
    )
# Out:
# <AxesSubplot:xlabel='value', ylabel='variable'>

# %% [markdown]
# ## Polynomial Regression with Lasso regularization

# %% [markdown]
# To do polynomial regression, we must first create the dataset will all the interactions and powers accordinglly we the got degree (3).
# However, notice that we have binary variables in our dataset which indicate the perturbation applied to the cell.
# Therefore, since we dont want $per\_AZD4573^2 = \{0,1\}^2 =per\_AZD4573$, then we need to remove those vars, then create the Polynomial dataset and finally add them:

# %% [markdown]
# ### Polynomial Lasso: Degree 2

# %%
X_temp, X_temp_names = get_polynomial_dataset(X_array=X.values, X_array_names=X.columns, degree=2, interaction_only=False)
print(X_temp.shape)
print(len(X_temp_names))
# Out:
# (13100, 813)
# 813

# %%
# Create and fit the Polynmial linear model with Lasso regularization:
poly_lasso = lm.Lasso(alpha=0.1, max_iter=10000).fit(X_temp[mask_cv], Y[mask_cv].values)

# %%
# Now save the coefficients
# First get the name of the vars and interactions:
poly_lasso_names = np.asarray(['intercept'] + X_temp_names)

# Now get the coefficient vals
poly_lasso_coef = np.round(np.append(poly_lasso.intercept_, poly_lasso.coef_), 4)

# Save only coefficients diff than 0
mask_coef = (poly_lasso_coef != 0)

# Create df
poly_lasso_coef_df_d2 = pd.DataFrame(poly_lasso_coef[mask_coef], columns=['coef'])
poly_lasso_coef_df_d2['var_name'] = poly_lasso_names[mask_coef]

# %%
# Save fitted values
predictions_df['y_Poly_Lasso_d2'] = poly_lasso.predict(X_temp)

# %%
# Get number of predictors
k = poly_lasso_coef_df_d2['coef'].shape[0]
# Get and save metrics values for this model
temp_metrics_df = calculate_and_save_metric_vals(df=predictions_df, y_model='y_Poly_Lasso_d2', k=k)
metric_vals_df = metric_vals_df.append(temp_metrics_df, ignore_index=True)

# %%
#plot_coef(poly_lasso_coef_df_d2)

# %% [markdown]
# ### Polynomial Lasso: Degree 3

# %%
X_temp, X_temp_names = get_polynomial_dataset(X_array=X.values, X_array_names=X.columns, degree=3, interaction_only=False)
print(X_temp.shape)
print(len(X_temp_names))
# Out:
# (13100, 11239)
# 11239

# %%
# Create and fit the Polynmial linear model with Lasso regularization:
poly_lasso = lm.Lasso(alpha=0.1, max_iter=10000).fit(X_temp[mask_cv], Y[mask_cv].values)

# %%
# Now save the coefficients
# First get the name of the vars and interactions:
poly_lasso_names = np.asarray(['intercept'] + X_temp_names)

# Now get the coefficient vals
poly_lasso_coef = np.round(np.append(poly_lasso.intercept_, poly_lasso.coef_), 4)

# Save only coefficients diff than 0
mask_coef = (poly_lasso_coef != 0)

# Create df
poly_lasso_coef_df_d3 = pd.DataFrame(poly_lasso_coef[mask_coef], columns=['coef'])
poly_lasso_coef_df_d3['var_name'] = poly_lasso_names[mask_coef]

# %%
# Save fitted values
predictions_df['y_Poly_Lasso_d3'] = poly_lasso.predict(X_temp)

# %%
# Get number of predictors
k = poly_lasso_coef_df_d3['coef'].shape[0]
# Get and save metrics values for this model
temp_metrics_df = calculate_and_save_metric_vals(df=predictions_df, y_model='y_Poly_Lasso_d3', k=k)
metric_vals_df = metric_vals_df.append(temp_metrics_df, ignore_index=True)

# %%
#plot_coef(poly_lasso_coef_df_d3)

# %% [markdown]
# ## Models Analysis

# %% [markdown]
# Puesto que tenemos mas puntos con perturbation que inhiben el TR => al hacer fit el modelo hace "mas" fit para la mayoria i.e. los puntos con suprimen el TR.

# %%
N = metadata.shape[0]

neutral_per = ['normal', 'DMSO', 'TSA']
n_neutral = np.sum([np.sum(metadata['perturbation'] == per) for per in neutral_per])

inter_per = ['CX5461']
n_inter = np.sum([np.sum(metadata['perturbation'] == per) for per in inter_per])

strong_per = ['AZD4573', 'Meayamycin', 'Triptolide']
n_strong = np.sum([np.sum(metadata['perturbation'] == per) for per in strong_per])

print('Percentgae of cells with neutral perturbation: {}%'.format(round(100*n_neutral/N,2)))
print('Percentgae of cells with intermediate perturbation: {}%'.format(round(100*n_inter/N,2)))
print('Percentgae of cells with Strong perturbation: {}%'.format(round(100*n_strong/N,2)))
# Out:
# Percentgae of cells with neutral perturbation: 41.42%
# Percentgae of cells with intermediate perturbation: 11.91%
# Percentgae of cells with Strong perturbation: 46.67%

# %%
# Depper look into error distribution per model
plot_error_dist(predictions_df[mask_cv], y_models)

# %% [markdown]
# #TODO
#
# #Add a heat map with the mse and the mae (maybe also r2)

# %%
# Save results so far
model_path = '/home/hhughes/Documents/Master_Thesis/Project/workspace/models/Linear_models'
    
with open(os.path.join(model_path, 'Predictions.csv'), 'w') as file:
    predictions_df.to_csv(file, index=False)
    
with open(os.path.join(model_path, 'Metric_vals.csv'), 'w') as file:
    metric_vals_df.to_csv(file, index=False)
    
with open(os.path.join(model_path, 'Coefficients.csv'), 'w') as file:
    coef_df.to_csv(file, index=False)
    
with open(os.path.join(model_path, 'Coefficients_poly_lasso_d2.csv'), 'w') as file:
    poly_lasso_coef_df_d2.to_csv(file, index=False)

with open(os.path.join(model_path, 'Coefficients_poly_lasso_d3.csv'), 'w') as file:
    poly_lasso_coef_df_d3.to_csv(file, index=False)

# %%
# Load results
model_path = '/home/hhughes/Documents/Master_Thesis/Project/workspace/models/Linear_models'

# Load files
with open(os.path.join(model_path, 'Predictions.csv'), 'r') as file:
    predictions_df = pd.read_csv(file)

with open(os.path.join(model_path, 'Metric_vals.csv'), 'r') as file:
    metric_vals_df = pd.read_csv(file)

with open(os.path.join(model_path, 'Coefficients.csv'), 'r') as file:
    coef_df = pd.read_csv(file)
    
with open(os.path.join(model_path, 'Coefficients_poly_lasso_d2.csv'), 'r') as file:
    poly_lasso_coef_df_d2 = pd.read_csv(file)

with open(os.path.join(model_path, 'Coefficients_poly_lasso_d3.csv'), 'r') as file:
    poly_lasso_coef_df_d2 = pd.read_csv(file)

# %%
metric_vals_df
# Out:
#             model    set      R2         BIC        MSE      MAE
# 0     ols_no_indi  train  0.8188  78324.3005  1721.1921  31.2837
# 1     ols_no_indi    val  0.8150   9986.5676  1787.6698  31.4532
# 2     ols_no_indi   test  0.8259  10092.9312  1653.0568  31.0243
# 3         elastic  train  0.8803  74001.1168  1136.9366  24.0304
# 4         elastic    val  0.8846   9386.6410  1114.8970  24.0239
# 5         elastic   test  0.8836   9572.8396  1105.6818  24.0689
# 6           ridge  train  0.8802  74044.0892  1137.5826  24.0763
# 7           ridge    val  0.8836   9426.7120  1124.6983  24.1412
# 8           ridge   test  0.8830   9608.5570  1111.4781  24.1672
# 9           Lasso  train  0.8803  74001.1168  1136.9366  24.0304
# 10          Lasso    val  0.8846   9386.6410  1114.8970  24.0239
# 11          Lasso   test  0.8836   9572.8396  1105.6818  24.0689
# 12  Poly_Lasso_d2  train  0.8921  73057.4117  1024.3498  22.2412
# 13  Poly_Lasso_d2    val  0.8976   9345.4199   988.9501  22.3162
# 14  Poly_Lasso_d2   test  0.8930   9576.0460  1016.4206  22.4142
# 15  Poly_Lasso_d3  train  0.8946  72989.6329  1000.7873  22.0128
# 16  Poly_Lasso_d3    val  0.9009   9439.5857   957.4742  22.0264
# 17  Poly_Lasso_d3   test  0.8946   9691.8172  1000.5762  22.2305
